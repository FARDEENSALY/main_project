# %% [markdown]
# # Pets Facial Expression Classification with EfficientNetB5
# * Understanding pets' facial expressions is pivotal in animal behavior research and enhancing human-pet interactions. The project's goal is to create a dependable classifier using convolutional neural networks (CNNs), capable of identifying various pet expressions with precision.
#
# ## Introduction
# * The model is based on the EfficientNetB5 architecture, known for its efficiency and effectiveness in image classification tasks. Employing a dataset named "Pets Facial Expression," consisting of 1000 images, and incorporating extensive data augmentation techniques like rotation and distortion, the model achieves a notable test accuracy of 93%.
# * The primary difference in this model, aside from the EfficientNetB5 base model, lies in the image size 224 x 224, where given a larger size of pixels data the model would be able to learn a more refined detail than an image size of 128 x 128.
# * The second difference is data augmentation. in previous models, no data rotation and distortion were applied onto exitsing data to create new data. This leads to the model being only able to identify undistored images. Yet with data augementation, the increased dataset where images are distorted, would enable the model to be more robust as it is also trained to indentify emotion from deformed signals.
#
# ## EfficientNetB5 Overview
# EfficientNetB5 is part of the EfficientNet family, a group of models designed by Mingxing Tan and Quoc V. Le, which have set new benchmarks for efficiency and accuracy in image classification tasks. These models utilize a novel scaling method that uniformly scales all dimensions of depth, width, and resolution, leveraging a compound coefficient. EfficientNetB5, specifically, offers an optimal balance between performance and computational cost, making it a suitable choice for this task.
#
# ## Data Description
# The dataset comprises 1000 images divided into 'Other', 'Angry', 'Sad', and 'Happy' classes, with an equitable distribution of 800 training, 120 validation, and 80 testing images.
#
# ## Methodology
# - **Data Augmentation:** Data augmentation strategies, including rotation, distortion, and other techniques, are extensively used to enhance the model's generalization capability.
# - **Model Architecture:**
#   - **Base Model:** The EfficientNetB5, pre-trained on the ImageNet dataset, is employed for its proven efficiency in image classification.
#   - **Additional Layers:** Layers like batch normalization, dense layers with ReLU activation and regularizers, and a dropout layer, are added post the base model.
#   - **Output Layer:** A dense layer with softmax activation is tailored for the four classes.
# - **Compilation and Callbacks:**
#   - The model is compiled using the Adamax optimizer and categorical crossentropy loss function, focusing on accuracy.
#   - Early Stopping and Learning Rate Scheduler are used as callbacks.
# - **Training:** The model is trained for 100 epochs with a batch size of 16 using the augmented dataset.
#
# ## Results and Discussion
# Achieving a test accuracy of 93.75%, the model's success is attributed to the EfficientNetB5 architecture and the diverse data augmentation techniques. The EfficientNetB5's ability to efficiently handle image classification tasks is evident in the high accuracy achieved. The balance in parameters underlines the model's adept adaptation for pet facial expression classification.
#
# |            | Precision | Recall | F1-Score | Support |
# |------------|-----------|--------|----------|---------|
# | Angry      | 0.97      | 0.93   | 0.95     | 30      |
# | Other      | 0.87      | 1.00   | 0.93     | 13      |
# | Sad        | 0.95      | 0.90   | 0.92     | 20      |
# | Happy      | 0.94      | 0.94   | 0.94     | 17      |
# | **Accuracy**   |           |        | **0.94**    | 80      |
# | **Macro Avg**  | 0.93      | 0.94   | 0.94     | 80      |
# | **Weighted Avg**| 0.94      | 0.94   | 0.94     | 80      |
#
# ## Conclusion
# This project illustrates the potential of deep learning, particularly using EfficientNetB5, in classifying pet facial expressions with high accuracy. It lays the groundwork for future research into more complex models, larger datasets, and real-world applications in animal behavior and veterinary sciences.
#
# ## References
# - TensorFlow and Keras Documentation.
# - EfficientNet: Rethinking Model Scaling for Convolutional Neural Networks (Tan and Le, 2019).
# - Data Augmentation Techniques in Deep Learning.
#
# This report, enriched with an introduction to EfficientNetB5, reflects the model's high capability in accurately classifying pet facial expressions, as evidenced by the 93.75% test accuracy.

# %% [markdown]
# <div style="text-align: left; background-color:black; font-family: Trebuchet MS; color:#007ACC; padding: 12px; line-height:1.25;border-radius:1px; margin-bottom: 0em; text-align: center; font-size: 58px;border-style: solid;border-color: green solid;"> Pet Facial Expression </div>

# %% [markdown]
# <center>
#     <img src='https://dogexpress.in/wp-content/uploads/2017/07/Dogs-With-Funny-Facial-Expressions-1-660x330.jpg'>
# </center>

# %% [markdown]
#    <a id='top'></a>
# <div class="list-group" id="list-tab" role="tablist"></div>
#
# ## <div style="background-color:#007ACC;font-family:Trebuchet MS;color:#FFF9ED;font-size:150%;text-align:center;border-radius:9px 9px; padding: 15px; border-style: solid; border-color: black">TABLE OF CONTENTS</div>
#
# * [1. Introduction](#1)
#
# * [2. Import Necessaries](#2)
#
# * [3. EDA](#3)
#
#     * [3.1. Define data path and dataset name](#3.1)
#     * [3.2. Create Dataframe for the dataset](#3.2)
#     * [3.3. Display Number of Examples in the dataset](#3.3)
#     * [3.4. Display Number of Classes in the dataset](#3.4)
#     * [3.5. Display count of images in each class of the dataset](#3.5)
#     * [3.6. Visualize Each Class in the dataset](#3.6)
#     * [3.7. Check Null values in the dataframe](#3.7)
#     * [3.8. Visualize Null values](#3.8)
#
#
# * [4. Split dataframe into train, valid, and test](#4)
#
# * [5. Create Image Data Generator](#5)
#
# * [6. Visualize Training dataset](#6)
#
# * [7. Model Structure](#7)
#
#     * [7.1. Generic Model Creation](#7.1)
#     * [7.2. Define Early Stop](#7.2)
#     * [7.3. Train model](#7.3)
#
#
# * [8. Evaluate Model](#8)
#
#     * [8.1. Plot accuarcy and loss curve](#8.1)
#     * [8.2. Model Accuarcy](#8.2)
#     * [8.3. Get Predictions](#8.3)
#
#
# * [9. Save the Model](#9)
#
# * [10. Load Model ](#10)

# %% [markdown]
# <a id="1"></a>
# ## <b>1 <span style='color:#B21010'>||</span> Introduction</b>

# %% [markdown]
# <div style="background-color:#007ACC;
#             border-radius:9px 9px;
#             border: black solid;
#             padding: 15px;
#             color:#FFF9ED;
#             font-family:Trebuchet MS;
#             font-size:150%;
#             text-align: center">
# <h3 style='border:0; border-radius: 5px; color: white'><center> STEPS </center></h3>
# </div>
# _________________________________________________________________________
#
#
# 1. Load the data by storing each image path in a list and its corresponding label in another list<br>
# 2. Transform the lists into dataframe<br>
# 3. EDA and analyze the data for more insights
# 4. Split the data into train, test and validation datasets<br>
# 5. Create Data Generator for Train, Test and validation datasets<br>
# Tensorflow Generators are very useful to Generate batches of tensor image data with real-time data augmentation.<br>
# 6. Load the pretrained model, add some layers on top of its base layer and compile it<br>
# We will be using EffiecentNet, of course you can use any pretrained model you want and tune its architecture and parameters!<br>
# 7. Evaluate the model by plotting acc and loss curves, plot confussion matrix and print classification report<br>
# 8. Save the model to use it in production<br>
# 9. Finally, Load the model and make predictions

# %% [markdown]
# <a id="2"></a>
# ## <b>2 <span style='color:#B21010'>||</span> Import Necessaries</b>

# %%
import os
import itertools

import cv2
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_style('darkgrid')
import matplotlib.pyplot as plt
import missingno as msno
from plotly.subplots import make_subplots
import plotly.graph_objects as go
from plotly.offline import iplot

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam, Adamax
from tensorflow.keras.metrics import categorical_crossentropy
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Activation, Dropout, BatchNormalization
from tensorflow.keras import regularizers
from keras.callbacks import EarlyStopping, LearningRateScheduler
import numpy as np
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.efficientnet import preprocess_input

# Ignore Warnings
import warnings
warnings.filterwarnings("ignore")

print ('modules loaded')
# Out:
# modules loaded

# %% [markdown]
# <a id="3"></a>
# ## <b>3 <span style='color:#B21010'>||</span> EDA</b>

# %% [markdown]
# <a id="3.1"></a>
# ### <b>3.1 <span style='color:#B21010'>||</span> Define data path and dataset name</b>

# %%
train_data_dir = 'pets_facial_expression_dataset/master/train'
valid_data_dir = 'pets_facial_expression_dataset/master/valid'
test_data_dir = 'pets_facial_expression_dataset/master/test'

data_dir = 'pets_facial_expression_dataset'


ds_name = 'Pets Facial Expression'

# %% [markdown]
# <a id="3.2"></a>
# ### <b>3.2 <span style='color:#B21010'>||</span> Create Dataframe for the dataset</b>

# %%
# Generate data paths with labels

def generate_data_paths(data_dir):
    
    filepaths = []
    labels = []

    folds = os.listdir(data_dir)
    for fold in folds:
        if fold == 'master':
            continue
            
        foldpath = os.path.join(data_dir, fold)
        filelist = os.listdir(foldpath)
        for file in filelist:
            fpath = os.path.join(foldpath, file)
            filepaths.append(fpath)
            labels.append(fold)
            
    return filepaths, labels


filepaths, labels = generate_data_paths(data_dir)

# %%
def create_df(filepaths, labels):

    Fseries = pd.Series(filepaths, name= 'filepaths')
    Lseries = pd.Series(labels, name='labels')
    df = pd.concat([Fseries, Lseries], axis= 1)
    return df

df = create_df(filepaths, labels)

# %%
df.head()
# Out:
#                                      filepaths labels
# 0  pets_facial_expression_dataset\Angry\02.jpg  Angry
# 1  pets_facial_expression_dataset\Angry\03.jpg  Angry
# 2  pets_facial_expression_dataset\Angry\04.jpg  Angry
# 3  pets_facial_expression_dataset\Angry\05.jpg  Angry
# 4  pets_facial_expression_dataset\Angry\06.jpg  Angry

# %% [markdown]
# <a id="3.3"></a>
# ### <b>3.3 <span style='color:#B21010'>||</span> Display Number of Examples in the dataset</b>

# %%
def num_of_examples(df, name='df'):
    print(f"The {name} dataset has {df.shape[0]} images.")
    
num_of_examples(df, ds_name)
# Out:
# The Pets Facial Expression dataset has 1000 images.

# %% [markdown]
# <a id="3.4"></a>
# ### <b>3.4 <span style='color:#B21010'>||</span> Display Number of Classes in the dataset</b>

# %%
def num_of_classes(df, name='df'):
    print(f"The {name} dataset has {len(df['labels'].unique())} classes")
    
num_of_classes(df, ds_name)
# Out:
# The Pets Facial Expression dataset has 4 classes

# %% [markdown]
# <a id="3.5"></a>
# ### <b>3.5 <span style='color:#B21010'>||</span> Display count of images in each class of the dataset</b>

# %%
def classes_count(df, name='df'):
    
    print(f"The {name} dataset has: ")
    print("="*70)
    print()
    for name in df['labels'].unique():
        num_class = len(df['labels'][df['labels'] == name])
        print(f"Class '{name}' has {num_class} images")
        print('-'*70)
        
classes_count(df, ds_name)
# Out:
# The Pets Facial Expression dataset has:
# ======================================================================
#
# Class 'Angry' has 250 images
# ----------------------------------------------------------------------
# Class 'happy' has 250 images
# ----------------------------------------------------------------------
# Class 'Other' has 250 images
# ----------------------------------------------------------------------
# Class 'Sad' has 250 images
# ----------------------------------------------------------------------

# %% [markdown]
# <a id="3.6"></a>
# ### <b>3.6 <span style='color:#B21010'>||</span> Visualize Each Class in the dataset</b>

# %%
# Create Model Structure
img_size = (224, 224)
channels = 3
img_shape = (img_size[0], img_size[1], channels)
# determine class_count robustly: use train_gen if available, otherwise infer from dataset folders
try:
    class_count = len(list(train_gen.class_indices.keys())) # to define number of classes in dense layer
except NameError:
    import os
    train_dir = 'pets_facial_expression_dataset/master/train'
    if os.path.exists(train_dir):
        class_count = len([d for d in os.listdir(train_dir) if os.path.isdir(os.path.join(train_dir, d))])
    else:
        # fallback to 4 classes (Angry, Other, Sad, Happy)
        class_count = 4

# create pre-trained model (you can build on pretrained model such as :  efficientnet, VGG , Resnet )
# we will use efficientnetb5 from EfficientNet family.
base_model = tf.keras.applications.efficientnet.EfficientNetB5(include_top= False, weights= "imagenet", input_shape= img_shape, pooling= 'max')
base_model.trainable = False

model = Sequential([
    base_model,
    BatchNormalization(axis= -1, momentum= 0.99, epsilon= 0.001),
    Dense(256, activation='relu'),
    Dense(128, kernel_regularizer= regularizers.l2(0.016), activity_regularizer= regularizers.l1(0.006),
                bias_regularizer= regularizers.l1(0.006), activation= 'relu'),
    Dropout(rate= 0.45, seed= 123),
    Dense(class_count, activation= 'softmax')
])

model.compile(Adamax(learning_rate= 0.001), loss= 'categorical_crossentropy', metrics= ['accuracy'])

model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ efficientnetb5 (Functional)     │ (None, 2048)           │    28,513,527 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 2048)           │         8,192 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 256)            │       524,544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 4)              │           516 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 29,079,675 (110.93 MB)
#  Trainable params: 562,052 (2.14 MB)
#  Non-trainable params: 28,517,623 (108.79 MB)

# %% [markdown]
# <a id="3.7"></a>
# ### <b>3.7 <span style='color:#B21010'>||</span> Check Null values in the dataframe</b>

# %%
def check_null_values(df, name='df'):
    
    num_null_vals = sum(df.isnull().sum().values)
    
    if not num_null_vals:
        print(f"The {name} dataset has no null values")
    
    else:
        print(f"The {name} dataset has {num_null_vals} null values")
        print('-'*70)
        print('Total null values in each column:\n')
        print(df.isnull().sum())
        

check_null_values(df, ds_name)
# Out:
# The Pets Facial Expression dataset has no null values

# %% [markdown]
# <a id="3.8"></a>
# ### <b>3.8 <span style='color:#B21010'>||</span> Visualize Null values</b>

# %%
msno.matrix(df)
plt.title('Distribution of Missing Values', fontsize=30, fontstyle='oblique');

# %% [markdown]
# <a id="4"></a>
# ## <b>4 <span style='color:#B21010'>||</span>Split dataframe into train, valid, and test</b>

# %%
# train dataframe
train_df, dummy_df = train_test_split(df,  train_size= 0.8, shuffle= True, random_state= 123)

# valid and test dataframe
valid_df, test_df = train_test_split(dummy_df,  train_size= 0.6, shuffle= True, random_state= 123)

# %%
'''
filepaths, labels = generate_data_paths(train_data_dir)
train_df = create_df(filepaths, labels)

filepaths, labels = generate_data_paths(valid_data_dir)
valid_df = create_df(filepaths, labels)

filepaths, labels = generate_data_paths(test_data_dir)
test_df = create_df(filepaths, labels)
'''
# Out:
# '\nfilepaths, labels = generate_data_paths(train_data_dir)\ntrain_df = create_df(filepaths, labels)\n\nfilepaths, labels = generate_data_paths(valid_data_dir)\nvalid_df = create_df(filepaths, labels)\n\nfilepaths, labels = generate_data_paths(test_data_dir)\ntest_df = create_df(filepaths, labels)\n'

# %%
num_of_examples(train_df, "Training "+ds_name)
num_of_examples(valid_df, "Validation "+ds_name)
num_of_examples(test_df, "Testing "+ds_name)
# Out:
# The Training Pets Facial Expression dataset has 800 images.
# The Validation Pets Facial Expression dataset has 120 images.
# The Testing Pets Facial Expression dataset has 80 images.

# %%
num_of_classes(train_df, "Training "+ds_name)
num_of_classes(valid_df, "Validation "+ds_name)
num_of_classes(test_df, "Testing "+ds_name)
# Out:
# The Training Pets Facial Expression dataset has 4 classes
# The Validation Pets Facial Expression dataset has 4 classes
# The Testing Pets Facial Expression dataset has 4 classes

# %%
classes_count(train_df, 'Training '+ds_name)
# Out:
# The Training Pets Facial Expression dataset has:
# ======================================================================
#
# Class 'Other' has 209 images
# ----------------------------------------------------------------------
# Class 'Sad' has 192 images
# ----------------------------------------------------------------------
# Class 'happy' has 201 images
# ----------------------------------------------------------------------
# Class 'Angry' has 198 images
# ----------------------------------------------------------------------

# %%
classes_count(valid_df, 'Validation '+ds_name)
# Out:
# The Validation Pets Facial Expression dataset has:
# ======================================================================
#
# Class 'happy' has 29 images
# ----------------------------------------------------------------------
# Class 'Other' has 28 images
# ----------------------------------------------------------------------
# Class 'Angry' has 35 images
# ----------------------------------------------------------------------
# Class 'Sad' has 28 images
# ----------------------------------------------------------------------

# %%
classes_count(test_df, 'Testing '+ds_name)
# Out:
# The Testing Pets Facial Expression dataset has:
# ======================================================================
#
# Class 'Angry' has 17 images
# ----------------------------------------------------------------------
# Class 'happy' has 20 images
# ----------------------------------------------------------------------
# Class 'Sad' has 30 images
# ----------------------------------------------------------------------
# Class 'Other' has 13 images
# ----------------------------------------------------------------------

# %% [markdown]
# <a id="5"></a>
# ## <b>5 <span style='color:#B21010'>||</span>Create Image Data Generator</b>

# %%
# crobed image size
batch_size = 16
img_size = (224, 224)
channels = 3
img_shape = (img_size[0], img_size[1], channels)

# Recommended : use custom function for test data batch size, else we can use normal batch size.
ts_length = len(test_df)
test_batch_size = max(sorted([ts_length // n for n in range(1, ts_length + 1) if ts_length%n == 0 and ts_length/n <= 80]))
test_steps = ts_length // test_batch_size

# This function which will be used in image data generator for data augmentation, it just take the image and return it again.
def scalar(img):
    return img

tr_gen = ImageDataGenerator(preprocessing_function= scalar,
                           rotation_range=40,
                           width_shift_range=0.2,
                           height_shift_range=0.2,
                           brightness_range=[0.4,0.6],
                           zoom_range=0.3,
                           horizontal_flip=True,
                           vertical_flip=True)

ts_gen = ImageDataGenerator(preprocessing_function= scalar,
                           rotation_range=40,
                           width_shift_range=0.2,
                           height_shift_range=0.2,
                           brightness_range=[0.4,0.6],
                           zoom_range=0.3,
                           horizontal_flip=True,
                           vertical_flip=True)

train_gen = tr_gen.flow_from_dataframe(train_df, 
                                       x_col= 'filepaths', 
                                       y_col= 'labels', 
                                       target_size= img_size, 
                                       class_mode= 'categorical',
                                       color_mode= 'rgb', 
                                       shuffle= True, 
                                       batch_size= batch_size)

valid_gen = ts_gen.flow_from_dataframe(valid_df, 
                                       x_col= 'filepaths', 
                                       y_col= 'labels', 
                                       target_size= img_size, 
                                       class_mode= 'categorical',
                                       color_mode= 'rgb', 
                                       shuffle= True, 
                                       batch_size= batch_size)

# Note: we will use custom test_batch_size, and make shuffle= false
test_gen = ts_gen.flow_from_dataframe(test_df, 
                                      x_col= 'filepaths', 
                                      y_col= 'labels', 
                                      target_size= img_size, 
                                      class_mode= 'categorical',
                                      color_mode= 'rgb', 
                                      shuffle= False, 
                                      batch_size= test_batch_size)
# Out:
# Found 800 validated image filenames belonging to 4 classes.
# Found 120 validated image filenames belonging to 4 classes.
# Found 120 validated image filenames belonging to 4 classes.
# Found 80 validated image filenames belonging to 4 classes.
# Found 80 validated image filenames belonging to 4 classes.

# %% [markdown]
# <a id="6"></a>
# ## <b>6 <span style='color:#B21010'>||</span>Visualize Training dataset</b>

# %%
g_dict = train_gen.class_indices      # defines dictionary {'class': index}
classes = list(g_dict.keys())       # defines list of dictionary's kays (classes), classes names : string
images, labels = next(train_gen)      # get a batch size samples from the generator

plt.figure(figsize= (20, 20))

for i in range(16):
    plt.subplot(4, 4, i + 1)
    image = images[i] / 255       # scales data to range (0 - 255)
    plt.imshow(image)
    index = np.argmax(labels[i])  # get image index
    class_name = classes[index]   # get class of image
    plt.title(class_name, color= 'blue', fontsize= 12)
    plt.axis('off')
    
plt.show()

# %% [markdown]
# <a id="7"></a>
# ## <b>7 <span style='color:#B21010'>||</span>Model Structure</b>

# %% [markdown]
# <a id="7.1"></a>
# ### <b>7.1 <span style='color:#B21010'>||</span>Generic Model Creation</b>

# %%
# Create Model Structure
img_size = (224, 224)
channels = 3
img_shape = (img_size[0], img_size[1], channels)
# determine class_count robustly: use train_gen if available, otherwise infer from dataset folders
try:
    class_count = len(list(train_gen.class_indices.keys())) # to define number of classes in dense layer
except NameError:
    import os
    train_dir = 'pets_facial_expression_dataset/master/train'
    if os.path.exists(train_dir):
        class_count = len([d for d in os.listdir(train_dir) if os.path.isdir(os.path.join(train_dir, d))])
    else:
        # fallback to 4 classes (Angry, Other, Sad, Happy)
        class_count = 4

# create pre-trained model (you can built on pretrained model such as :  efficientnet, VGG , Resnet )
# we will use efficientnetb5 from EfficientNet family.
base_model = tf.keras.applications.efficientnet.EfficientNetB5(include_top= False, weights= "imagenet", input_shape= img_shape, pooling= 'max')
base_model.trainable = False

model = Sequential([
    base_model,
    BatchNormalization(axis= -1, momentum= 0.99, epsilon= 0.001),
    Dense(256, activation='relu'),
    Dense(128, kernel_regularizer= regularizers.l2(0.016), activity_regularizer= regularizers.l1(0.006),
                bias_regularizer= regularizers.l1(0.006), activation= 'relu'),
    Dropout(rate= 0.45, seed= 123),
    Dense(class_count, activation= 'softmax')
])

model.compile(Adamax(learning_rate= 0.001), loss= 'categorical_crossentropy', metrics= ['accuracy'])

model.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ efficientnetb5 (Functional)     │ (None, 2048)           │    28,513,527 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 2048)           │         8,192 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 256)            │       524,544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_14 (Dense)                │ (None, 4)              │           516 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 29,079,675 (110.93 MB)
#  Trainable params: 562,052 (2.14 MB)
#  Non-trainable params: 28,517,623 (108.79 MB)

# %% [markdown]
# <a id="7.2"></a>
# ### <b>7.2 <span style='color:#B21010'>||</span>Define Early Stop</b>

# %%
early_stopping = EarlyStopping(monitor='val_accuracy', 
                               patience=5, 
                               restore_best_weights=True,
                               mode='max',
                              )

def step_decay(epoch):
    
     initial_lrate = 0.1
     drop = 0.5
     epochs_drop = 10.0
     lrate = initial_lrate * math.pow(drop, math.floor((1+epoch)/epochs_drop))
     return lrate

lr_scheduler = LearningRateScheduler(step_decay)

# %% [markdown]
# <a id="7.3"></a>
# ### <b>7.3 <span style='color:#B21010'>||</span>Train Model</b>

# %%
batch_size = 16   # set batch size for training
epochs = 100   # number of all epochs in training

history = model.fit(x=train_gen,
                    epochs= epochs,
                    verbose= 1,
                    validation_data= valid_gen, 
                    validation_steps= None,
                    shuffle= False)
# Out:
# Epoch 1/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 90s 1s/step - accuracy: 0.3176 - loss: 6.4901 - val_accuracy: 0.3833 - val_loss: 4.1790
# Epoch 2/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 90s 1s/step - accuracy: 0.3176 - loss: 6.4901 - val_accuracy: 0.3833 - val_loss: 4.1790
# Epoch 2/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.3387 - loss: 4.0610 - val_accuracy: 0.3750 - val_loss: 3.9366
# Epoch 3/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.3387 - loss: 4.0610 - val_accuracy: 0.3750 - val_loss: 3.9366
# Epoch 3/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.3405 - loss: 3.8633 - val_accuracy: 0.4333 - val_loss: 3.7259
# Epoch 4/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.3405 - loss: 3.8633 - val_accuracy: 0.4333 - val_loss: 3.7259
# Epoch 4/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.3508 - loss: 3.6946 - val_accuracy: 0.4417 - val_loss: 3.5739
# Epoch 5/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.3508 - loss: 3.6946 - val_accuracy: 0.4417 - val_loss: 3.5739
# Epoch 5/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.3357 - loss: 3.5481 - val_accuracy: 0.4000 - val_loss: 3.4440
# Epoch 6/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.3357 - loss: 3.5481 - val_accuracy: 0.4000 - val_loss: 3.4440
# Epoch 6/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.3503 - loss: 3.4159 - val_accuracy: 0.3917 - val_loss: 3.3067
# Epoch 7/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.3503 - loss: 3.4159 - val_accuracy: 0.3917 - val_loss: 3.3067
# Epoch 7/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.3068 - loss: 3.2881 - val_accuracy: 0.3833 - val_loss: 3.1904
# Epoch 8/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.3068 - loss: 3.2881 - val_accuracy: 0.3833 - val_loss: 3.1904
# Epoch 8/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.3018 - loss: 3.1679 - val_accuracy: 0.3000 - val_loss: 3.0731
# Epoch 9/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.3018 - loss: 3.1679 - val_accuracy: 0.3000 - val_loss: 3.0731
# Epoch 9/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.3443 - loss: 3.0414 - val_accuracy: 0.4000 - val_loss: 2.9558
# Epoch 10/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.3443 - loss: 3.0414 - val_accuracy: 0.4000 - val_loss: 2.9558
# Epoch 10/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.3622 - loss: 2.9289 - val_accuracy: 0.4167 - val_loss: 2.8603
# Epoch 11/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.3622 - loss: 2.9289 - val_accuracy: 0.4167 - val_loss: 2.8603
# Epoch 11/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.3670 - loss: 2.8299 - val_accuracy: 0.4167 - val_loss: 2.7521
# Epoch 12/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.3670 - loss: 2.8299 - val_accuracy: 0.4167 - val_loss: 2.7521
# Epoch 12/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.3946 - loss: 2.7241 - val_accuracy: 0.4250 - val_loss: 2.6480
# Epoch 13/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.3946 - loss: 2.7241 - val_accuracy: 0.4250 - val_loss: 2.6480
# Epoch 13/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.3754 - loss: 2.6295 - val_accuracy: 0.3917 - val_loss: 2.5725
# Epoch 14/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.3754 - loss: 2.6295 - val_accuracy: 0.3917 - val_loss: 2.5725
# Epoch 14/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.3602 - loss: 2.5378 - val_accuracy: 0.4167 - val_loss: 2.4722
# Epoch 15/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.3602 - loss: 2.5378 - val_accuracy: 0.4167 - val_loss: 2.4722
# Epoch 15/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.3768 - loss: 2.4537 - val_accuracy: 0.4750 - val_loss: 2.3937
# Epoch 16/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.3768 - loss: 2.4537 - val_accuracy: 0.4750 - val_loss: 2.3937
# Epoch 16/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.4053 - loss: 2.3751 - val_accuracy: 0.5000 - val_loss: 2.3123
# Epoch 17/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.4053 - loss: 2.3751 - val_accuracy: 0.5000 - val_loss: 2.3123
# Epoch 17/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.4291 - loss: 2.2919 - val_accuracy: 0.5083 - val_loss: 2.2256
# Epoch 18/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.4291 - loss: 2.2919 - val_accuracy: 0.5083 - val_loss: 2.2256
# Epoch 18/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.3981 - loss: 2.2263 - val_accuracy: 0.5583 - val_loss: 2.1479
# Epoch 19/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.3981 - loss: 2.2263 - val_accuracy: 0.5583 - val_loss: 2.1479
# Epoch 19/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.4462 - loss: 2.1430 - val_accuracy: 0.4917 - val_loss: 2.1034
# Epoch 20/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.4462 - loss: 2.1430 - val_accuracy: 0.4917 - val_loss: 2.1034
# Epoch 20/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.4019 - loss: 2.0940 - val_accuracy: 0.5417 - val_loss: 2.0296
# Epoch 21/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.4019 - loss: 2.0940 - val_accuracy: 0.5417 - val_loss: 2.0296
# Epoch 21/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.4530 - loss: 2.0297 - val_accuracy: 0.5417 - val_loss: 1.9414
# Epoch 22/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.4530 - loss: 2.0297 - val_accuracy: 0.5417 - val_loss: 1.9414
# Epoch 22/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.4465 - loss: 1.9610 - val_accuracy: 0.4833 - val_loss: 1.9177
# Epoch 23/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.4465 - loss: 1.9610 - val_accuracy: 0.4833 - val_loss: 1.9177
# Epoch 23/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.4436 - loss: 1.9200 - val_accuracy: 0.5667 - val_loss: 1.8323
# Epoch 24/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.4436 - loss: 1.9200 - val_accuracy: 0.5667 - val_loss: 1.8323
# Epoch 24/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.4671 - loss: 1.8528 - val_accuracy: 0.5833 - val_loss: 1.7912
# Epoch 25/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.4671 - loss: 1.8528 - val_accuracy: 0.5833 - val_loss: 1.7912
# Epoch 25/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.4336 - loss: 1.8107 - val_accuracy: 0.5833 - val_loss: 1.7361
# Epoch 26/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.4336 - loss: 1.8107 - val_accuracy: 0.5833 - val_loss: 1.7361
# Epoch 26/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.4752 - loss: 1.7639 - val_accuracy: 0.5750 - val_loss: 1.7124
# Epoch 27/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.4752 - loss: 1.7639 - val_accuracy: 0.5750 - val_loss: 1.7124
# Epoch 27/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.4494 - loss: 1.7324 - val_accuracy: 0.5667 - val_loss: 1.6675
# Epoch 28/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.4494 - loss: 1.7324 - val_accuracy: 0.5667 - val_loss: 1.6675
# Epoch 28/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.4612 - loss: 1.7105 - val_accuracy: 0.6583 - val_loss: 1.6192
# Epoch 29/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.4612 - loss: 1.7105 - val_accuracy: 0.6583 - val_loss: 1.6192
# Epoch 29/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.4604 - loss: 1.6736 - val_accuracy: 0.5917 - val_loss: 1.5931
# Epoch 30/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.4604 - loss: 1.6736 - val_accuracy: 0.5917 - val_loss: 1.5931
# Epoch 30/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.4634 - loss: 1.6249 - val_accuracy: 0.6167 - val_loss: 1.5712
# Epoch 31/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.4634 - loss: 1.6249 - val_accuracy: 0.6167 - val_loss: 1.5712
# Epoch 31/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.4694 - loss: 1.6037 - val_accuracy: 0.6417 - val_loss: 1.5338
# Epoch 32/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.4694 - loss: 1.6037 - val_accuracy: 0.6417 - val_loss: 1.5338
# Epoch 32/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.4898 - loss: 1.5602 - val_accuracy: 0.6333 - val_loss: 1.5008
# Epoch 33/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.4898 - loss: 1.5602 - val_accuracy: 0.6333 - val_loss: 1.5008
# Epoch 33/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.4868 - loss: 1.5600 - val_accuracy: 0.6250 - val_loss: 1.4850
# Epoch 34/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.4868 - loss: 1.5600 - val_accuracy: 0.6250 - val_loss: 1.4850
# Epoch 34/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 71s 1s/step - accuracy: 0.4590 - loss: 1.5378 - val_accuracy: 0.6167 - val_loss: 1.4694
# Epoch 35/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 71s 1s/step - accuracy: 0.4590 - loss: 1.5378 - val_accuracy: 0.6167 - val_loss: 1.4694
# Epoch 35/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.5495 - loss: 1.4759 - val_accuracy: 0.6167 - val_loss: 1.4322
# Epoch 36/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.5495 - loss: 1.4759 - val_accuracy: 0.6167 - val_loss: 1.4322
# Epoch 36/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 72s 1s/step - accuracy: 0.5160 - loss: 1.4755 - val_accuracy: 0.6333 - val_loss: 1.4115
# Epoch 37/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 72s 1s/step - accuracy: 0.5160 - loss: 1.4755 - val_accuracy: 0.6333 - val_loss: 1.4115
# Epoch 37/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 71s 1s/step - accuracy: 0.5348 - loss: 1.4367 - val_accuracy: 0.6083 - val_loss: 1.3887
# Epoch 38/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 71s 1s/step - accuracy: 0.5348 - loss: 1.4367 - val_accuracy: 0.6083 - val_loss: 1.3887
# Epoch 38/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 71s 1s/step - accuracy: 0.5423 - loss: 1.4167 - val_accuracy: 0.6333 - val_loss: 1.3579
# Epoch 39/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 71s 1s/step - accuracy: 0.5423 - loss: 1.4167 - val_accuracy: 0.6333 - val_loss: 1.3579
# Epoch 39/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 71s 1s/step - accuracy: 0.5339 - loss: 1.3882 - val_accuracy: 0.6500 - val_loss: 1.3112
# Epoch 40/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 71s 1s/step - accuracy: 0.5339 - loss: 1.3882 - val_accuracy: 0.6500 - val_loss: 1.3112
# Epoch 40/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 71s 1s/step - accuracy: 0.5478 - loss: 1.3741 - val_accuracy: 0.6167 - val_loss: 1.3184
# Epoch 41/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 71s 1s/step - accuracy: 0.5478 - loss: 1.3741 - val_accuracy: 0.6167 - val_loss: 1.3184
# Epoch 41/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 71s 1s/step - accuracy: 0.5611 - loss: 1.3608 - val_accuracy: 0.6500 - val_loss: 1.3058
# Epoch 42/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 71s 1s/step - accuracy: 0.5611 - loss: 1.3608 - val_accuracy: 0.6500 - val_loss: 1.3058
# Epoch 42/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 71s 1s/step - accuracy: 0.5404 - loss: 1.3659 - val_accuracy: 0.6167 - val_loss: 1.2996
# Epoch 43/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 71s 1s/step - accuracy: 0.5404 - loss: 1.3659 - val_accuracy: 0.6167 - val_loss: 1.2996
# Epoch 43/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 71s 1s/step - accuracy: 0.5530 - loss: 1.3713 - val_accuracy: 0.6583 - val_loss: 1.2719
# Epoch 44/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 71s 1s/step - accuracy: 0.5530 - loss: 1.3713 - val_accuracy: 0.6583 - val_loss: 1.2719
# Epoch 44/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 72s 1s/step - accuracy: 0.5592 - loss: 1.3327 - val_accuracy: 0.7000 - val_loss: 1.2524
# Epoch 45/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 72s 1s/step - accuracy: 0.5592 - loss: 1.3327 - val_accuracy: 0.7000 - val_loss: 1.2524
# Epoch 45/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 71s 1s/step - accuracy: 0.5752 - loss: 1.3336 - val_accuracy: 0.6083 - val_loss: 1.3103
# Epoch 46/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 71s 1s/step - accuracy: 0.5752 - loss: 1.3336 - val_accuracy: 0.6083 - val_loss: 1.3103
# Epoch 46/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 71s 1s/step - accuracy: 0.5802 - loss: 1.3060 - val_accuracy: 0.6250 - val_loss: 1.2904
# Epoch 47/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 71s 1s/step - accuracy: 0.5802 - loss: 1.3060 - val_accuracy: 0.6250 - val_loss: 1.2904
# Epoch 47/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 71s 1s/step - accuracy: 0.5696 - loss: 1.2975 - val_accuracy: 0.6583 - val_loss: 1.2400
# Epoch 48/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 71s 1s/step - accuracy: 0.5696 - loss: 1.2975 - val_accuracy: 0.6583 - val_loss: 1.2400
# Epoch 48/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 71s 1s/step - accuracy: 0.5443 - loss: 1.3119 - val_accuracy: 0.6833 - val_loss: 1.2024
# Epoch 49/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 71s 1s/step - accuracy: 0.5443 - loss: 1.3119 - val_accuracy: 0.6833 - val_loss: 1.2024
# Epoch 49/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 71s 1s/step - accuracy: 0.5365 - loss: 1.2986 - val_accuracy: 0.6667 - val_loss: 1.1956
# Epoch 50/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 71s 1s/step - accuracy: 0.5365 - loss: 1.2986 - val_accuracy: 0.6667 - val_loss: 1.1956
# Epoch 50/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 71s 1s/step - accuracy: 0.5762 - loss: 1.2725 - val_accuracy: 0.6500 - val_loss: 1.2047
# Epoch 51/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 71s 1s/step - accuracy: 0.5762 - loss: 1.2725 - val_accuracy: 0.6500 - val_loss: 1.2047
# Epoch 51/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 71s 1s/step - accuracy: 0.5769 - loss: 1.2627 - val_accuracy: 0.7333 - val_loss: 1.1840
# Epoch 52/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 71s 1s/step - accuracy: 0.5769 - loss: 1.2627 - val_accuracy: 0.7333 - val_loss: 1.1840
# Epoch 52/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 71s 1s/step - accuracy: 0.5835 - loss: 1.2613 - val_accuracy: 0.6917 - val_loss: 1.1833
# Epoch 53/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 71s 1s/step - accuracy: 0.5835 - loss: 1.2613 - val_accuracy: 0.6917 - val_loss: 1.1833
# Epoch 53/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 71s 1s/step - accuracy: 0.5631 - loss: 1.2358 - val_accuracy: 0.7000 - val_loss: 1.1538
# Epoch 54/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 71s 1s/step - accuracy: 0.5631 - loss: 1.2358 - val_accuracy: 0.7000 - val_loss: 1.1538
# Epoch 54/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 71s 1s/step - accuracy: 0.6011 - loss: 1.2312 - val_accuracy: 0.6917 - val_loss: 1.1384
# Epoch 55/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 71s 1s/step - accuracy: 0.6011 - loss: 1.2312 - val_accuracy: 0.6917 - val_loss: 1.1384
# Epoch 55/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 71s 1s/step - accuracy: 0.6372 - loss: 1.2111 - val_accuracy: 0.7167 - val_loss: 1.1675
# Epoch 56/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 71s 1s/step - accuracy: 0.6372 - loss: 1.2111 - val_accuracy: 0.7167 - val_loss: 1.1675
# Epoch 56/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.5850 - loss: 1.2403 - val_accuracy: 0.7250 - val_loss: 1.1525
# Epoch 57/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.5850 - loss: 1.2403 - val_accuracy: 0.7250 - val_loss: 1.1525
# Epoch 57/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.6183 - loss: 1.1761 - val_accuracy: 0.7333 - val_loss: 1.1365
# Epoch 58/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.6183 - loss: 1.1761 - val_accuracy: 0.7333 - val_loss: 1.1365
# Epoch 58/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 74s 1s/step - accuracy: 0.6207 - loss: 1.1949 - val_accuracy: 0.7500 - val_loss: 1.1165
# Epoch 59/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 74s 1s/step - accuracy: 0.6207 - loss: 1.1949 - val_accuracy: 0.7500 - val_loss: 1.1165
# Epoch 59/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 75s 2s/step - accuracy: 0.6359 - loss: 1.1672 - val_accuracy: 0.7250 - val_loss: 1.0929
# Epoch 60/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 75s 2s/step - accuracy: 0.6359 - loss: 1.1672 - val_accuracy: 0.7250 - val_loss: 1.0929
# Epoch 60/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 75s 2s/step - accuracy: 0.6726 - loss: 1.1309 - val_accuracy: 0.6917 - val_loss: 1.1099
# Epoch 61/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 75s 2s/step - accuracy: 0.6726 - loss: 1.1309 - val_accuracy: 0.6917 - val_loss: 1.1099
# Epoch 61/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 77s 2s/step - accuracy: 0.6270 - loss: 1.1614 - val_accuracy: 0.7250 - val_loss: 1.0842
# Epoch 62/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 77s 2s/step - accuracy: 0.6270 - loss: 1.1614 - val_accuracy: 0.7250 - val_loss: 1.0842
# Epoch 62/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 76s 2s/step - accuracy: 0.6244 - loss: 1.1852 - val_accuracy: 0.7750 - val_loss: 1.0417
# Epoch 63/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 76s 2s/step - accuracy: 0.6244 - loss: 1.1852 - val_accuracy: 0.7750 - val_loss: 1.0417
# Epoch 63/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 80s 2s/step - accuracy: 0.6692 - loss: 1.1211 - val_accuracy: 0.7083 - val_loss: 1.0927
# Epoch 64/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 80s 2s/step - accuracy: 0.6692 - loss: 1.1211 - val_accuracy: 0.7083 - val_loss: 1.0927
# Epoch 64/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 71s 1s/step - accuracy: 0.6147 - loss: 1.1682 - val_accuracy: 0.6750 - val_loss: 1.1063
# Epoch 65/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 71s 1s/step - accuracy: 0.6147 - loss: 1.1682 - val_accuracy: 0.6750 - val_loss: 1.1063
# Epoch 65/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.6485 - loss: 1.1261 - val_accuracy: 0.7000 - val_loss: 1.0527
# Epoch 66/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.6485 - loss: 1.1261 - val_accuracy: 0.7000 - val_loss: 1.0527
# Epoch 66/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.6469 - loss: 1.1125 - val_accuracy: 0.7500 - val_loss: 1.0525
# Epoch 67/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.6469 - loss: 1.1125 - val_accuracy: 0.7500 - val_loss: 1.0525
# Epoch 67/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.6821 - loss: 1.1104 - val_accuracy: 0.7250 - val_loss: 1.0322
# Epoch 68/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.6821 - loss: 1.1104 - val_accuracy: 0.7250 - val_loss: 1.0322
# Epoch 68/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.6669 - loss: 1.1025 - val_accuracy: 0.7583 - val_loss: 1.0363
# Epoch 69/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.6669 - loss: 1.1025 - val_accuracy: 0.7583 - val_loss: 1.0363
# Epoch 69/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.6635 - loss: 1.1086 - val_accuracy: 0.7583 - val_loss: 0.9909
# Epoch 70/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.6635 - loss: 1.1086 - val_accuracy: 0.7583 - val_loss: 0.9909
# Epoch 70/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.6779 - loss: 1.0841 - val_accuracy: 0.6833 - val_loss: 1.0281
# Epoch 71/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.6779 - loss: 1.0841 - val_accuracy: 0.6833 - val_loss: 1.0281
# Epoch 71/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.6621 - loss: 1.0832 - val_accuracy: 0.7583 - val_loss: 1.0552
# Epoch 72/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.6621 - loss: 1.0832 - val_accuracy: 0.7583 - val_loss: 1.0552
# Epoch 72/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.6890 - loss: 1.0555 - val_accuracy: 0.7917 - val_loss: 0.9896
# Epoch 73/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.6890 - loss: 1.0555 - val_accuracy: 0.7917 - val_loss: 0.9896
# Epoch 73/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.7036 - loss: 1.0444 - val_accuracy: 0.7583 - val_loss: 0.9912
# Epoch 74/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.7036 - loss: 1.0444 - val_accuracy: 0.7583 - val_loss: 0.9912
# Epoch 74/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.7085 - loss: 1.0409 - val_accuracy: 0.7667 - val_loss: 0.9804
# Epoch 75/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.7085 - loss: 1.0409 - val_accuracy: 0.7667 - val_loss: 0.9804
# Epoch 75/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.7177 - loss: 1.0516 - val_accuracy: 0.7833 - val_loss: 0.9699
# Epoch 76/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.7177 - loss: 1.0516 - val_accuracy: 0.7833 - val_loss: 0.9699
# Epoch 76/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.7612 - loss: 1.0038 - val_accuracy: 0.7583 - val_loss: 1.0058
# Epoch 77/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.7612 - loss: 1.0038 - val_accuracy: 0.7583 - val_loss: 1.0058
# Epoch 77/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.7305 - loss: 1.0591 - val_accuracy: 0.7917 - val_loss: 0.9193
# Epoch 78/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.7305 - loss: 1.0591 - val_accuracy: 0.7917 - val_loss: 0.9193
# Epoch 78/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.7566 - loss: 1.0333 - val_accuracy: 0.8083 - val_loss: 0.8975
# Epoch 79/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.7566 - loss: 1.0333 - val_accuracy: 0.8083 - val_loss: 0.8975
# Epoch 79/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.7178 - loss: 1.0218 - val_accuracy: 0.8250 - val_loss: 0.8929
# Epoch 80/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.7178 - loss: 1.0218 - val_accuracy: 0.8250 - val_loss: 0.8929
# Epoch 80/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.7689 - loss: 0.9822 - val_accuracy: 0.8083 - val_loss: 0.9348
# Epoch 81/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.7689 - loss: 0.9822 - val_accuracy: 0.8083 - val_loss: 0.9348
# Epoch 81/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.7263 - loss: 1.0331 - val_accuracy: 0.7917 - val_loss: 0.9196
# Epoch 82/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.7263 - loss: 1.0331 - val_accuracy: 0.7917 - val_loss: 0.9196
# Epoch 82/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.7791 - loss: 0.9841 - val_accuracy: 0.8333 - val_loss: 0.9051
# Epoch 83/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.7791 - loss: 0.9841 - val_accuracy: 0.8333 - val_loss: 0.9051
# Epoch 83/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.7572 - loss: 0.9857 - val_accuracy: 0.8333 - val_loss: 0.9206
# Epoch 84/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.7572 - loss: 0.9857 - val_accuracy: 0.8333 - val_loss: 0.9206
# Epoch 84/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.7907 - loss: 0.9226 - val_accuracy: 0.8583 - val_loss: 0.8784
# Epoch 85/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.7907 - loss: 0.9226 - val_accuracy: 0.8583 - val_loss: 0.8784
# Epoch 85/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.7419 - loss: 0.9870 - val_accuracy: 0.8000 - val_loss: 0.9059
# Epoch 86/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.7419 - loss: 0.9870 - val_accuracy: 0.8000 - val_loss: 0.9059
# Epoch 86/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.7809 - loss: 0.9812 - val_accuracy: 0.8167 - val_loss: 0.9005
# Epoch 87/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.7809 - loss: 0.9812 - val_accuracy: 0.8167 - val_loss: 0.9005
# Epoch 87/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.7656 - loss: 0.9511 - val_accuracy: 0.8417 - val_loss: 0.9179
# Epoch 88/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.7656 - loss: 0.9511 - val_accuracy: 0.8417 - val_loss: 0.9179
# Epoch 88/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.7811 - loss: 0.9301 - val_accuracy: 0.8417 - val_loss: 0.8437
# Epoch 89/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.7811 - loss: 0.9301 - val_accuracy: 0.8417 - val_loss: 0.8437
# Epoch 89/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.7948 - loss: 0.9229 - val_accuracy: 0.8500 - val_loss: 0.8666
# Epoch 90/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.7948 - loss: 0.9229 - val_accuracy: 0.8500 - val_loss: 0.8666
# Epoch 90/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.7828 - loss: 0.9494 - val_accuracy: 0.8750 - val_loss: 0.8554
# Epoch 91/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.7828 - loss: 0.9494 - val_accuracy: 0.8750 - val_loss: 0.8554
# Epoch 91/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.7949 - loss: 0.9424 - val_accuracy: 0.8083 - val_loss: 0.8338
# Epoch 92/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.7949 - loss: 0.9424 - val_accuracy: 0.8083 - val_loss: 0.8338
# Epoch 92/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.7499 - loss: 0.9781 - val_accuracy: 0.9000 - val_loss: 0.7728
# Epoch 93/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.7499 - loss: 0.9781 - val_accuracy: 0.9000 - val_loss: 0.7728
# Epoch 93/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.7909 - loss: 0.9353 - val_accuracy: 0.8583 - val_loss: 0.7867
# Epoch 94/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.7909 - loss: 0.9353 - val_accuracy: 0.8583 - val_loss: 0.7867
# Epoch 94/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.8022 - loss: 0.9236 - val_accuracy: 0.8500 - val_loss: 0.8035
# Epoch 95/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.8022 - loss: 0.9236 - val_accuracy: 0.8500 - val_loss: 0.8035
# Epoch 95/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.8094 - loss: 0.8931 - val_accuracy: 0.8333 - val_loss: 0.8261
# Epoch 96/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.8094 - loss: 0.8931 - val_accuracy: 0.8333 - val_loss: 0.8261
# Epoch 96/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.7903 - loss: 0.9052 - val_accuracy: 0.9000 - val_loss: 0.7447
# Epoch 97/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.7903 - loss: 0.9052 - val_accuracy: 0.9000 - val_loss: 0.7447
# Epoch 97/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.8003 - loss: 0.8944 - val_accuracy: 0.9000 - val_loss: 0.7789
# Epoch 98/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.8003 - loss: 0.8944 - val_accuracy: 0.9000 - val_loss: 0.7789
# Epoch 98/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.8254 - loss: 0.8408 - val_accuracy: 0.8750 - val_loss: 0.7818
# Epoch 99/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.8254 - loss: 0.8408 - val_accuracy: 0.8750 - val_loss: 0.7818
# Epoch 99/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.8244 - loss: 0.8779 - val_accuracy: 0.8417 - val_loss: 0.7744
# Epoch 100/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.8244 - loss: 0.8779 - val_accuracy: 0.8417 - val_loss: 0.7744
# Epoch 100/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.8464 - loss: 0.8318 - val_accuracy: 0.8583 - val_loss: 0.7754
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.8464 - loss: 0.8318 - val_accuracy: 0.8583 - val_loss: 0.7754

# %% [markdown]
# <a id="8"></a>
# ## <b>8 <span style='color:#B21010'>||</span>Evaluate Model</b>

# %% [markdown]
# <a id="8.1"></a>
# ### <b>8.1 <span style='color:#B21010'>||</span>Plot accuarcy and loss curve </b>

# %%
# Define needed variables
tr_acc = history.history['accuracy']
tr_loss = history.history['loss']
val_acc = history.history['val_accuracy']
val_loss = history.history['val_loss']
index_loss = np.argmin(val_loss)
val_lowest = val_loss[index_loss]
index_acc = np.argmax(val_acc)
acc_highest = val_acc[index_acc]
Epochs = [i+1 for i in range(len(tr_acc))]
loss_label = f'best epoch= {str(index_loss + 1)}'
acc_label = f'best epoch= {str(index_acc + 1)}'

# Plot training history

plt.figure(figsize= (20, 8))
plt.style.use('fivethirtyeight')

plt.subplot(1, 2, 1)
plt.plot(Epochs, tr_loss, 'r', label= 'Training loss')
plt.plot(Epochs, val_loss, 'g', label= 'Validation loss')
plt.scatter(index_loss + 1, val_lowest, s= 150, c= 'blue', label= loss_label)
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(Epochs, tr_acc, 'r', label= 'Training Accuracy')
plt.plot(Epochs, val_acc, 'g', label= 'Validation Accuracy')
plt.scatter(index_acc + 1 , acc_highest, s= 150, c= 'blue', label= acc_label)
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout
plt.show()

# %% [markdown]
# <a id="8.2"></a>
# ### <b>8.2 <span style='color:#B21010'>||</span>Model Accuarcy</b>

# %%
ts_length = len(test_df)
test_batch_size = max(sorted([ts_length // n for n in range(1, ts_length + 1) if ts_length%n == 0 and ts_length/n <= 80]))
test_steps = ts_length // test_batch_size

train_score = model.evaluate(train_gen, steps= test_steps, verbose= 1)
valid_score = model.evaluate(valid_gen, steps= test_steps, verbose= 1)
test_score = model.evaluate(test_gen, steps= test_steps, verbose= 1)

print("Train Loss: ", train_score[0])
print("Train Accuracy: ", train_score[1])
print('-' * 20)
print("Test Loss: ", test_score[0])
print("Test Accuracy: ", test_score[1])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9375 - loss: 0.6510
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9375 - loss: 0.6510
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8750 - loss: 0.9397
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8750 - loss: 0.9397
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - accuracy: 0.7625 - loss: 1.7610
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - accuracy: 0.7625 - loss: 1.7610
# Train Loss:  0.6509553790092468
# Train Accuracy:  0.9375
# --------------------
# Test Loss:  1.7609691619873047
# Test Accuracy:  0.762499988079071
# Train Loss:  0.6509553790092468
# Train Accuracy:  0.9375
# --------------------
# Test Loss:  1.7609691619873047
# Test Accuracy:  0.762499988079071

# %% [markdown]
# <a id="8.3"></a>
# ### <b>8.3 <span style='color:#B21010'>||</span>Get Prediction</b>

# %%
# Use model.predict with DataFrameIterator (predict_generator deprecated)
preds = model.predict(test_gen, verbose=1)
y_pred = np.argmax(preds, axis=1)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 11s 11s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 11s 11s/step

# %% [markdown]
# <a id="8.4"></a>
# ### <b>8.4 <span style='color:#B21010'>||</span>Confussion Matrix</b>

# %%
g_dict = test_gen.class_indices
classes = list(g_dict.keys())

# Confusion matrix
cm = confusion_matrix(test_gen.classes, y_pred)

plt.figure(figsize= (10, 10))
plt.imshow(cm, interpolation= 'nearest', cmap= plt.cm.Blues)
plt.title('Confusion Matrix')
plt.colorbar()

tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes, rotation= 45)
plt.yticks(tick_marks, classes)


thresh = cm.max() / 2.
for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    plt.text(j, i, cm[i, j], horizontalalignment= 'center', color= 'white' if cm[i, j] > thresh else 'black')

plt.tight_layout()
plt.ylabel('True Label')
plt.xlabel('Predicted Label')

plt.show()

# %% [markdown]
# <a id="8.5"></a>
# ### <b>8.5 <span style='color:#B21010'>||</span>Classification Report</b>

# %%
# Classification report
print(classification_report(test_gen.classes, y_pred, target_names= classes))
# Out:
#               precision    recall  f1-score   support
#
#        Angry       0.67      0.94      0.78        17
#        Other       0.86      0.92      0.89        13
#          Sad       0.86      0.63      0.73        30
#        happy       0.80      0.80      0.80        20
#
#     accuracy                           0.79        80
#    macro avg       0.80      0.82      0.80        80
# weighted avg       0.80      0.79      0.78        80

# %% [markdown]
# <a id="9"></a>
# ## <b>9 <span style='color:#B21010'>||</span>Save the Model</b>

# %%
model.save('efficientNetB5_pet_emotion_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# <a id="10"></a>
# ## <b>10 <span style='color:#B21010'>||</span>Load the model and Predict the Inputs</b>

# %%
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.efficientnet import preprocess_input

def predict_and_display(image_path, model):
    
    img = image.load_img(image_path, target_size=(224, 224))
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    img_array = preprocess_input(img_array)

    prediction = model.predict(img_array)
    predicted_class_index = np.argmax(prediction)
    
    class_indices = train_gen.class_indices
    class_labels = list(class_indices.keys())
    predicted_class_label = class_labels[predicted_class_index]
    
    plt.imshow(img)
    plt.axis('off')
    if predicted_class_label == 'Other':
        plt.title(f"The pet is normal")
    else:
        plt.title(f"The Pet is {predicted_class_label}")
    plt.show()

model.load_weights('efficientNetB5_pet_emotion_model.h5')

class_labels = ['Angry', 'Other', 'Sad', 'Happy']

# Replace 'path_to_test_image' with the path to the image you want to test
image_path_to_test = 'pets_facial_expression_dataset/Angry/02.jpg'
predict_and_display(image_path_to_test, model)
# Out:
# 1/1 [==============================] - 4s 4s/step

# %%
image_path_to_test = 'pets_facial_expression_dataset/Sad/031.jpg'
predict_and_display(image_path_to_test, model)
# Out:
# 1/1 [==============================] - 0s 212ms/step

# %%
image_path_to_test = 'pets_facial_expression_dataset/happy/032.jpg'
predict_and_display(image_path_to_test, model)
# Out:
# 1/1 [==============================] - 0s 295ms/step

# %%
image_path_to_test = 'pets_facial_expression_dataset/Other/20.jpg'
predict_and_display(image_path_to_test, model)
# Out:
# 1/1 [==============================] - 0s 238ms/step
